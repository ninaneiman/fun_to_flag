# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import os, sys, math, time
import fun_to_flag as ff
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
namefile='casa-20180726-084724.log'

ff.make_command(namefile, print_scan=False)
# Out:
# ALL LINES: 1170 NO REPEATERS 1086
# Spectral window: 25
# antennas:
# lim: 0.06 total # to flag: 2 max: 3 min: 3
# ANTENNA 23
# cols: [[23  3]]
# Channels:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# scans:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# mode='manual' antenna='ea23' spw='25:4' scan='67,69'
# ANTENNA 6
# cols: [[6 3]]
# Channels:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# scans:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# mode='manual' antenna='ea06' spw='25:4' scan='67,69'
#
# Spectral window: 2
# antennas:
# lim: 1.92 total # to flag: 7 max: 80 min: 5
# ANTENNA 23
# cols: [[23 80]]
# Channels:
# lim: 0.4 total # to flag: 40 max: 4 min: 1
# scans:
# lim: 0.4 total # to flag: 2 max: 78 min: 2
# mode='manual' antenna='ea23' spw='2:10~15,2:17~19,2:22~24,2:27~41,2:44~46,2:48~53,2:55~57,2:60' scan='5,71'
# ANTENNA 24
# cols: [[24 31]]
# Channels:
# lim: 0.155 total # to flag: 25 max: 2 min: 1
# scans:
# lim: 0.155 total # to flag: 1 max: 31 min: 31
# mode='manual' antenna='ea24' spw='2:10~15,2:23~24,2:29~35,2:41,2:45~46,2:49~51,2:55~57,2:60' scan='5'
# ANTENNA 3
# cols: [[ 3 31]]
# Channels:
# lim: 0.155 total # to flag: 24 max: 2 min: 1
# scans:
# lim: 0.155 total # to flag: 2 max: 30 min: 1
# mode='manual' antenna='ea03' spw='2:11~14,2:17~19,2:22~24,2:28~31,2:33,2:36,2:40~41,2:44~45,2:50~53' scan='5,102'
# ANTENNA 4
# cols: [[ 4 21]]
# Channels:
# lim: 0.105 total # to flag: 19 max: 2 min: 1
# scans:
# lim: 0.105 total # to flag: 1 max: 21 min: 21
# mode='manual' antenna='ea04' spw='2:10~12,2:18,2:27,2:30~32,2:34~39,2:41,2:48~49,2:52,2:56' scan='5'
# ANTENNA 6
# cols: [[ 6 10]]
# Channels:
# lim: 0.05 total # to flag: 8 max: 2 min: 1
# scans:
# lim: 0.05 total # to flag: 9 max: 2 min: 1
# mode='manual' antenna='ea06' spw='2:17~18,2:25,2:31,2:35,2:38~39,2:44' scan='17,23,31,37,43,51,71,100,102'
# ANTENNA 19
# cols: [[19  8]]
# Channels:
# lim: 0.04 total # to flag: 7 max: 2 min: 1
# scans:
# lim: 0.04 total # to flag: 5 max: 2 min: 1
# mode='manual' antenna='ea19' spw='2:10,2:18,2:25,2:32~33,2:37~38' scan='27,31,37,43,45'
# ANTENNA 15
# cols: [[15  5]]
# Channels:
# lim: 0.025 total # to flag: 5 max: 1 min: 1
# scans:
# lim: 0.025 total # to flag: 4 max: 2 min: 1
# mode='manual' antenna='ea15' spw='2:10,2:32~33,2:37~38' scan='27,31,37,45'
#
# Spectral window: 3
# antennas:
# lim: 1.02 total # to flag: 4 max: 47 min: 15
# ANTENNA 23
# cols: [[23 47]]
# Channels:
# lim: 0.235 total # to flag: 33 max: 3 min: 1
# scans:
# lim: 0.235 total # to flag: 1 max: 47 min: 47
# mode='manual' antenna='ea23' spw='3:3~4,3:6~7,3:10~20,3:23~24,3:26,3:28~29,3:31,3:33,3:35,3:41~47,3:52,3:57,3:59' scan='5'
# ANTENNA 24
# cols: [[24 21]]
# Channels:
# lim: 0.105 total # to flag: 18 max: 3 min: 1
# scans:
# lim: 0.105 total # to flag: 1 max: 21 min: 21
# mode='manual' antenna='ea24' spw='3:7,3:10~13,3:15,3:17~20,3:26,3:29,3:35,3:41,3:43,3:52,3:57,3:59' scan='5'
# ANTENNA 4
# cols: [[ 4 19]]
# Channels:
# lim: 0.095 total # to flag: 17 max: 2 min: 1
# scans:
# lim: 0.095 total # to flag: 1 max: 19 min: 19
# mode='manual' antenna='ea04' spw='3:4,3:6~7,3:10~14,3:23~24,3:29,3:31,3:43~47' scan='5'
# ANTENNA 3
# cols: [[ 3 15]]
# Channels:
# lim: 0.075 total # to flag: 13 max: 2 min: 1
# scans:
# lim: 0.075 total # to flag: 1 max: 15 min: 15
# mode='manual' antenna='ea03' spw='3:3,3:10~11,3:16~18,3:28~29,3:33,3:35,3:42,3:46~47' scan='5'
#
# Spectral window: 4
# antennas:
# lim: 1.38 total # to flag: 4 max: 64 min: 16
# ANTENNA 23
# cols: [[23 64]]
# Channels:
# lim: 0.32 total # to flag: 42 max: 3 min: 1
# scans:
# lim: 0.32 total # to flag: 1 max: 64 min: 64
# mode='manual' antenna='ea23' spw='4:3~8,4:10~17,4:21,4:23,4:25~35,4:37~38,4:44~45,4:47,4:50~56,4:58~60' scan='5'
# ANTENNA 3
# cols: [[ 3 29]]
# Channels:
# lim: 0.145 total # to flag: 24 max: 2 min: 1
# scans:
# lim: 0.145 total # to flag: 1 max: 29 min: 29
# mode='manual' antenna='ea03' spw='4:7~8,4:10~11,4:16~17,4:25~31,4:33~34,4:38,4:44~45,4:47,4:51,4:57~60' scan='5'
# ANTENNA 24
# cols: [[24 27]]
# Channels:
# lim: 0.135 total # to flag: 22 max: 2 min: 1
# scans:
# lim: 0.135 total # to flag: 1 max: 27 min: 27
# mode='manual' antenna='ea24' spw='4:4~7,4:11~12,4:23,4:26,4:28~29,4:31~32,4:34~35,4:38,4:45,4:50~52,4:57~58,4:60' scan='5'
# ANTENNA 4
# cols: [[ 4 16]]
# Channels:
# lim: 0.08 total # to flag: 15 max: 2 min: 1
# scans:
# lim: 0.08 total # to flag: 1 max: 16 min: 16
# mode='manual' antenna='ea04' spw='4:3~4,4:13~15,4:17,4:21,4:37~38,4:44~45,4:53~56' scan='5'
#
# Spectral window: 5
# antennas:
# lim: 1.1 total # to flag: 4 max: 55 min: 5
# ANTENNA 23
# cols: [[23 55]]
# Channels:
# lim: 0.275 total # to flag: 40 max: 3 min: 1
# scans:
# lim: 0.275 total # to flag: 1 max: 55 min: 55
# mode='manual' antenna='ea23' spw='5:3,5:6~7,5:11,5:14~15,5:17~21,5:25~34,5:37~40,5:42~46,5:48~50,5:52~53,5:55~58,5:60' scan='5'
# ANTENNA 4
# cols: [[ 4 26]]
# Channels:
# lim: 0.13 total # to flag: 23 max: 2 min: 1
# scans:
# lim: 0.13 total # to flag: 1 max: 26 min: 26
# mode='manual' antenna='ea04' spw='5:3,5:6~7,5:17~21,5:25~26,5:28~29,5:33~34,5:38~39,5:43~46,5:50,5:52~53' scan='5'
# ANTENNA 3
# cols: [[ 3 24]]
# Channels:
# lim: 0.12 total # to flag: 24 max: 1 min: 1
# scans:
# lim: 0.12 total # to flag: 1 max: 24 min: 24
# mode='manual' antenna='ea03' spw='5:11,5:14~15,5:18~21,5:27~28,5:31~33,5:39~40,5:42,5:45,5:48~49,5:53,5:55~58,5:60' scan='5'
# ANTENNA 24
# cols: [[24  5]]
# Channels:
# lim: 0.025 total # to flag: 5 max: 1 min: 1
# scans:
# lim: 0.025 total # to flag: 1 max: 5 min: 5
# mode='manual' antenna='ea24' spw='5:3,5:30,5:37~38,5:56' scan='5'
#
# Spectral window: 6
# antennas:
# lim: 1.22 total # to flag: 5 max: 55 min: 2
# ANTENNA 23
# cols: [[23 55]]
# Channels:
# lim: 0.275 total # to flag: 39 max: 4 min: 1
# scans:
# lim: 0.275 total # to flag: 1 max: 55 min: 55
# mode='manual' antenna='ea23' spw='6:3~8,6:11~14,6:16~17,6:19~21,6:23~30,6:32~35,6:38~39,6:47~49,6:52,6:55~60' scan='5'
# ANTENNA 24
# cols: [[24 27]]
# Channels:
# lim: 0.135 total # to flag: 24 max: 2 min: 1
# scans:
# lim: 0.135 total # to flag: 1 max: 27 min: 27
# mode='manual' antenna='ea24' spw='6:3,6:5~6,6:13,6:15,6:17,6:21,6:23~27,6:29~30,6:32~35,6:38~39,6:47~49,6:59' scan='5'
# ANTENNA 3
# cols: [[ 3 25]]
# Channels:
# lim: 0.125 total # to flag: 21 max: 2 min: 1
# scans:
# lim: 0.125 total # to flag: 2 max: 24 min: 1
# mode='manual' antenna='ea03' spw='6:6,6:11~16,6:19~20,6:24~25,6:33~34,6:49~50,6:52,6:56~60' scan='5,96'
# ANTENNA 4
# cols: [[ 4 10]]
# Channels:
# lim: 0.05 total # to flag: 10 max: 1 min: 1
# scans:
# lim: 0.05 total # to flag: 1 max: 10 min: 10
# mode='manual' antenna='ea04' spw='6:4~5,6:7~8,6:16,6:24,6:28~29,6:34,6:55' scan='5'
# ANTENNA 6
# cols: [[6 2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea06' spw='6:19,6:50' scan='41,96'
#
# Spectral window: 7
# antennas:
# lim: 0.76 total # to flag: 17 max: 15 min: 1
# ANTENNA 23
# cols: [[23 15]]
# Channels:
# lim: 0.075 total # to flag: 13 max: 2 min: 1
# scans:
# lim: 0.075 total # to flag: 2 max: 14 min: 1
# mode='manual' antenna='ea23' spw='7:4,7:7~8,7:19~20,7:24,7:27,7:31,7:37,7:44,7:51,7:58,7:60' scan='5,100'
# ANTENNA 3
# cols: [[ 3 12]]
# Channels:
# lim: 0.06 total # to flag: 11 max: 2 min: 1
# scans:
# lim: 0.06 total # to flag: 1 max: 12 min: 12
# mode='manual' antenna='ea03' spw='7:7~8,7:20,7:24,7:36~37,7:39,7:55,7:58~60' scan='5'
# ANTENNA 14
# cols: [[14  9]]
# Channels:
# lim: 0.045 total # to flag: 4 max: 3 min: 1
# scans:
# lim: 0.045 total # to flag: 8 max: 2 min: 1
# mode='manual' antenna='ea14' spw='7:3~4,7:10~11' scan='15,23,53,118,122,128,140,150'
# ANTENNA 24
# cols: [[24  8]]
# Channels:
# lim: 0.04 total # to flag: 8 max: 1 min: 1
# scans:
# lim: 0.04 total # to flag: 1 max: 8 min: 8
# mode='manual' antenna='ea24' spw='7:4,7:31,7:36,7:39,7:51,7:55,7:59~60' scan='5'
# ANTENNA 4
# cols: [[4 7]]
# Channels:
# lim: 0.035 total # to flag: 6 max: 2 min: 1
# scans:
# lim: 0.035 total # to flag: 4 max: 4 min: 1
# mode='manual' antenna='ea04' spw='7:3~4,7:8,7:19~20,7:27' scan='5,23,128,132'
# ANTENNA 11
# cols: [[11  5]]
# Channels:
# lim: 0.025 total # to flag: 4 max: 2 min: 1
# scans:
# lim: 0.025 total # to flag: 4 max: 2 min: 1
# mode='manual' antenna='ea11' spw='7:4,7:10~11,7:27' scan='37,118,132,140'
# ANTENNA 17
# cols: [[17  4]]
# Channels:
# lim: 0.02 total # to flag: 2 max: 2 min: 2
# scans:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# mode='manual' antenna='ea17' spw='7:44,7:46' scan='92,100,102,138'
# ANTENNA 7
# cols: [[7 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea07' spw='7:44,7:46,7:49' scan='53,92,102'
# ANTENNA 20
# cols: [[20  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea20' spw='7:54' scan='65,146'
# ANTENNA 19
# cols: [[19  2]]
# Channels:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea19' spw='7:27' scan='37,79'
# ANTENNA 13
# cols: [[13  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea13' spw='7:3,7:10' scan='15,150'
# ANTENNA 5
# cols: [[5 2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea05' spw='7:54' scan='65,146'
# ANTENNA 26
# cols: [[26  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea26' spw='7:46' scan='138'
# ANTENNA 18
# cols: [[18  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea18' spw='7:27' scan='79'
# ANTENNA 6
# cols: [[6 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea06' spw='7:49' scan='53'
# ANTENNA 2
# cols: [[2 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea02' spw='7:11' scan='53'
# ANTENNA 1
# cols: [[1 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea01' spw='7:3' scan='122'
#
# Spectral window: 8
# antennas:
# lim: 0.48 total # to flag: 10 max: 16 min: 1
# ANTENNA 23
# cols: [[23 16]]
# Channels:
# lim: 0.08 total # to flag: 13 max: 2 min: 1
# scans:
# lim: 0.08 total # to flag: 1 max: 16 min: 16
# mode='manual' antenna='ea23' spw='8:3,8:8~10,8:12,8:15,8:17,8:26,8:28,8:42~43,8:52~53' scan='5'
# ANTENNA 3
# cols: [[3 8]]
# Channels:
# lim: 0.04 total # to flag: 8 max: 1 min: 1
# scans:
# lim: 0.04 total # to flag: 5 max: 4 min: 1
# mode='manual' antenna='ea03' spw='8:8,8:10,8:12,8:15,8:17,8:38,8:58~59' scan='5,47,49,86,104'
# ANTENNA 24
# cols: [[24  6]]
# Channels:
# lim: 0.03 total # to flag: 5 max: 2 min: 1
# scans:
# lim: 0.03 total # to flag: 1 max: 6 min: 6
# mode='manual' antenna='ea24' spw='8:8~9,8:28,8:42,8:52' scan='5'
# ANTENNA 4
# cols: [[4 6]]
# Channels:
# lim: 0.03 total # to flag: 5 max: 2 min: 1
# scans:
# lim: 0.03 total # to flag: 1 max: 6 min: 6
# mode='manual' antenna='ea04' spw='8:3,8:15,8:26,8:43,8:53' scan='5'
# ANTENNA 6
# cols: [[6 4]]
# Channels:
# lim: 0.02 total # to flag: 3 max: 2 min: 1
# scans:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# mode='manual' antenna='ea06' spw='8:33,8:41,8:45' scan='19,37,39,41'
# ANTENNA 19
# cols: [[19  3]]
# Channels:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea19' spw='8:33,8:45' scan='37,39,41'
# ANTENNA 15
# cols: [[15  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea15' spw='8:15,8:38' scan='47,49'
# ANTENNA 27
# cols: [[27  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea27' spw='8:59' scan='86'
# ANTENNA 14
# cols: [[14  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea14' spw='8:41' scan='19'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='8:58' scan='104'
#
# Spectral window: 10
# antennas:
# lim: 1.92 total # to flag: 7 max: 77 min: 2
# ANTENNA 23
# cols: [[23 77]]
# Channels:
# lim: 0.385 total # to flag: 43 max: 4 min: 1
# scans:
# lim: 0.385 total # to flag: 3 max: 75 min: 1
# mode='manual' antenna='ea23' spw='10:3~13,10:16,10:18~22,10:26,10:32~34,10:36~39,10:41~48,10:50~51,10:53~60' scan='5,13,23'
# ANTENNA 3
# cols: [[ 3 53]]
# Channels:
# lim: 0.265 total # to flag: 30 max: 6 min: 1
# scans:
# lim: 0.265 total # to flag: 13 max: 39 min: 1
# mode='manual' antenna='ea03' spw='10:3~5,10:7~10,10:13~14,10:16,10:22,10:24,10:32,10:36~37,10:39,10:41~48,10:53~55,10:58~60' scan='5,13,23,37,41,43,47,49,104,106,108,112,124'
# ANTENNA 24
# cols: [[24 25]]
# Channels:
# lim: 0.125 total # to flag: 23 max: 2 min: 1
# scans:
# lim: 0.125 total # to flag: 1 max: 25 min: 25
# mode='manual' antenna='ea24' spw='10:3~5,10:9~10,10:12~13,10:19~22,10:24,10:32,10:43~44,10:46,10:48,10:50~51,10:53~54,10:56~57' scan='5'
# ANTENNA 4
# cols: [[ 4 25]]
# Channels:
# lim: 0.125 total # to flag: 24 max: 2 min: 1
# scans:
# lim: 0.125 total # to flag: 1 max: 25 min: 25
# mode='manual' antenna='ea04' spw='10:3,10:6,10:9~13,10:16,10:18,10:26,10:33~34,10:37~39,10:41~42,10:45,10:47~48,10:56~59' scan='5'
# ANTENNA 12
# cols: [[12  4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# mode='manual' antenna='ea12' spw='10:3,10:22,10:42,10:47' scan='104,106,108,112'
# ANTENNA 15
# cols: [[15  3]]
# Channels:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea15' spw='10:4' scan='37,43,49'
# ANTENNA 11
# cols: [[11  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# mode='manual' antenna='ea11' spw='10:4,10:14' scan='41'
#
# Spectral window: 11
# antennas:
# lim: 1.28 total # to flag: 4 max: 57 min: 7
# ANTENNA 23
# cols: [[23 57]]
# Channels:
# lim: 0.285 total # to flag: 38 max: 3 min: 1
# scans:
# lim: 0.285 total # to flag: 1 max: 57 min: 57
# mode='manual' antenna='ea23' spw='11:3,11:6,11:8,11:10~13,11:16~17,11:20~29,11:31~33,11:36~38,11:43~44,11:47~48,11:50,11:52~54,11:56~60' scan='5'
# ANTENNA 3
# cols: [[ 3 38]]
# Channels:
# lim: 0.19 total # to flag: 31 max: 2 min: 1
# scans:
# lim: 0.19 total # to flag: 1 max: 38 min: 38
# mode='manual' antenna='ea03' spw='11:3~4,11:8~12,11:16~17,11:19~27,11:29,11:31,11:36~37,11:47~48,11:52~54,11:56~59' scan='5'
# ANTENNA 24
# cols: [[24 25]]
# Channels:
# lim: 0.125 total # to flag: 22 max: 2 min: 1
# scans:
# lim: 0.125 total # to flag: 1 max: 25 min: 25
# mode='manual' antenna='ea24' spw='11:4,11:6,11:9~10,11:12~13,11:17,11:19~20,11:26,11:28~29,11:32~33,11:36~37,11:50,11:53~54,11:57,11:59~60' scan='5'
# ANTENNA 4
# cols: [[4 7]]
# Channels:
# lim: 0.035 total # to flag: 6 max: 2 min: 1
# scans:
# lim: 0.035 total # to flag: 2 max: 6 min: 1
# mode='manual' antenna='ea04' spw='11:8,11:13,11:38,11:43~44,11:48' scan='5,126'
#
# Spectral window: 12
# antennas:
# lim: 0.58 total # to flag: 6 max: 27 min: 1
# ANTENNA 23
# cols: [[23 27]]
# Channels:
# lim: 0.135 total # to flag: 17 max: 3 min: 1
# scans:
# lim: 0.135 total # to flag: 1 max: 27 min: 27
# mode='manual' antenna='ea23' spw='12:4~7,12:9,12:12~14,12:16~19,12:22,12:24~25,12:27~28' scan='5'
# ANTENNA 3
# cols: [[ 3 11]]
# Channels:
# lim: 0.055 total # to flag: 9 max: 2 min: 1
# scans:
# lim: 0.055 total # to flag: 1 max: 11 min: 11
# mode='manual' antenna='ea03' spw='12:4~7,12:9,12:13,12:25,12:27~28' scan='5'
# ANTENNA 24
# cols: [[24  9]]
# Channels:
# lim: 0.045 total # to flag: 8 max: 2 min: 1
# scans:
# lim: 0.045 total # to flag: 1 max: 9 min: 9
# mode='manual' antenna='ea24' spw='12:4~5,12:7,12:16~19,12:24' scan='5'
# ANTENNA 4
# cols: [[4 9]]
# Channels:
# lim: 0.045 total # to flag: 9 max: 1 min: 1
# scans:
# lim: 0.045 total # to flag: 1 max: 9 min: 9
# mode='manual' antenna='ea04' spw='12:4,12:9,12:12~14,12:17,12:22,12:24,12:28' scan='5'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='12:17' scan='23'
# ANTENNA 1
# cols: [[1 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea01' spw='12:17' scan='23'
#
# Spectral window: 13
# antennas:
# lim: 1.12 total # to flag: 6 max: 49 min: 4
# ANTENNA 23
# cols: [[23 49]]
# Channels:
# lim: 0.245 total # to flag: 38 max: 3 min: 1
# scans:
# lim: 0.245 total # to flag: 2 max: 48 min: 1
# mode='manual' antenna='ea23' spw='13:3~13,13:16~17,13:19~21,13:24~26,13:28,13:30,13:33~34,13:37~42,13:44,13:48~49,13:53~55,13:57~58,13:60' scan='5,75'
# ANTENNA 3
# cols: [[ 3 34]]
# Channels:
# lim: 0.17 total # to flag: 29 max: 2 min: 1
# scans:
# lim: 0.17 total # to flag: 1 max: 34 min: 34
# mode='manual' antenna='ea03' spw='13:3~12,13:19~20,13:24~26,13:30,13:33~34,13:37~39,13:42,13:48~49,13:53~54,13:57~58,13:60' scan='5'
# ANTENNA 24
# cols: [[24 12]]
# Channels:
# lim: 0.06 total # to flag: 10 max: 2 min: 1
# scans:
# lim: 0.06 total # to flag: 1 max: 12 min: 12
# mode='manual' antenna='ea24' spw='13:3,13:7,13:21,13:24,13:28,13:41,13:49,13:54~55,13:60' scan='5'
# ANTENNA 4
# cols: [[4 6]]
# Channels:
# lim: 0.03 total # to flag: 6 max: 1 min: 1
# scans:
# lim: 0.03 total # to flag: 1 max: 6 min: 6
# mode='manual' antenna='ea04' spw='13:8,13:13,13:16~17,13:40,13:44' scan='5'
# ANTENNA 12
# cols: [[12  5]]
# Channels:
# lim: 0.025 total # to flag: 5 max: 1 min: 1
# scans:
# lim: 0.025 total # to flag: 5 max: 1 min: 1
# mode='manual' antenna='ea12' spw='13:29,13:36,13:38,13:47~48' scan='9,29,39,86,98'
# ANTENNA 1
# cols: [[1 4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# mode='manual' antenna='ea01' spw='13:29,13:36,13:38,13:47' scan='9,29,86,98'
#
# Spectral window: 14
# antennas:
# lim: 1.2 total # to flag: 5 max: 55 min: 3
# ANTENNA 23
# cols: [[23 55]]
# Channels:
# lim: 0.275 total # to flag: 35 max: 3 min: 1
# scans:
# lim: 0.275 total # to flag: 1 max: 55 min: 55
# mode='manual' antenna='ea23' spw='14:3~5,14:10~13,14:15~20,14:24~25,14:31~33,14:35~39,14:43~47,14:49,14:51,14:53~54,14:56~58' scan='5'
# ANTENNA 3
# cols: [[ 3 27]]
# Channels:
# lim: 0.135 total # to flag: 23 max: 2 min: 1
# scans:
# lim: 0.135 total # to flag: 2 max: 26 min: 1
# mode='manual' antenna='ea03' spw='14:3~4,14:16~17,14:24~25,14:30~33,14:35~39,14:44~47,14:51,14:54,14:56~57' scan='5,104'
# ANTENNA 24
# cols: [[24 16]]
# Channels:
# lim: 0.08 total # to flag: 14 max: 2 min: 1
# scans:
# lim: 0.08 total # to flag: 1 max: 16 min: 16
# mode='manual' antenna='ea24' spw='14:3,14:12~13,14:16~17,14:25,14:30~32,14:46~47,14:53,14:56~57' scan='5'
# ANTENNA 4
# cols: [[ 4 16]]
# Channels:
# lim: 0.08 total # to flag: 15 max: 2 min: 1
# scans:
# lim: 0.08 total # to flag: 2 max: 15 min: 1
# mode='manual' antenna='ea04' spw='14:3,14:5,14:10~12,14:15,14:18~20,14:25,14:43,14:45,14:49,14:51,14:58' scan='5,140'
# ANTENNA 12
# cols: [[12  3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea12' spw='14:4,14:35,14:58' scan='25,41,104'
#
# Spectral window: 15
# antennas:
# lim: 1.1 total # to flag: 4 max: 55 min: 15
# ANTENNA 23
# cols: [[23 55]]
# Channels:
# lim: 0.275 total # to flag: 39 max: 4 min: 1
# scans:
# lim: 0.275 total # to flag: 1 max: 55 min: 55
# mode='manual' antenna='ea23' spw='15:3~5,15:8~14,15:16~17,15:19~20,15:22~23,15:27,15:29~31,15:35,15:37,15:39~42,15:44~45,15:47~53,15:55,15:57~58,15:60' scan='5'
# ANTENNA 3
# cols: [[ 3 22]]
# Channels:
# lim: 0.11 total # to flag: 20 max: 2 min: 1
# scans:
# lim: 0.11 total # to flag: 1 max: 22 min: 22
# mode='manual' antenna='ea03' spw='15:3~5,15:11~13,15:16~17,15:19,15:22~23,15:29~30,15:37,15:41,15:44~45,15:51~53' scan='5'
# ANTENNA 24
# cols: [[24 18]]
# Channels:
# lim: 0.09 total # to flag: 18 max: 1 min: 1
# scans:
# lim: 0.09 total # to flag: 1 max: 18 min: 18
# mode='manual' antenna='ea24' spw='15:4,15:8~12,15:27,15:31,15:35,15:39~42,15:48~49,15:57~58,15:60' scan='5'
# ANTENNA 4
# cols: [[ 4 15]]
# Channels:
# lim: 0.075 total # to flag: 13 max: 2 min: 1
# scans:
# lim: 0.075 total # to flag: 1 max: 15 min: 15
# mode='manual' antenna='ea04' spw='15:4,15:9,15:12,15:14,15:20,15:47,15:49~53,15:55,15:60' scan='5'
#
# Spectral window: 16
# antennas:
# lim: 0.82 total # to flag: 4 max: 39 min: 11
# ANTENNA 23
# cols: [[23 39]]
# Channels:
# lim: 0.195 total # to flag: 28 max: 2 min: 1
# scans:
# lim: 0.195 total # to flag: 1 max: 39 min: 39
# mode='manual' antenna='ea23' spw='16:3,16:5~6,16:10~11,16:14~17,16:20,16:22,16:24,16:26~29,16:36,16:39,16:44~53' scan='5'
# ANTENNA 3
# cols: [[ 3 20]]
# Channels:
# lim: 0.1 total # to flag: 19 max: 2 min: 1
# scans:
# lim: 0.1 total # to flag: 1 max: 20 min: 20
# mode='manual' antenna='ea03' spw='16:3,16:6,16:11,16:14~17,16:24,16:26~27,16:29,16:36,16:47~53' scan='5'
# ANTENNA 4
# cols: [[ 4 12]]
# Channels:
# lim: 0.06 total # to flag: 11 max: 2 min: 1
# scans:
# lim: 0.06 total # to flag: 1 max: 12 min: 12
# mode='manual' antenna='ea04' spw='16:3,16:5,16:10,16:20,16:22,16:44~49' scan='5'
# ANTENNA 24
# cols: [[24 11]]
# Channels:
# lim: 0.055 total # to flag: 10 max: 2 min: 1
# scans:
# lim: 0.055 total # to flag: 1 max: 11 min: 11
# mode='manual' antenna='ea24' spw='16:10~11,16:26~29,16:39,16:45~46,16:52' scan='5'
#
# Spectral window: 17
# antennas:
# lim: 0.9 total # to flag: 6 max: 43 min: 1
# ANTENNA 23
# cols: [[23 43]]
# Channels:
# lim: 0.215 total # to flag: 34 max: 3 min: 1
# scans:
# lim: 0.215 total # to flag: 1 max: 43 min: 43
# mode='manual' antenna='ea23' spw='17:11,17:13~14,17:16,17:18~26,17:28~29,17:32~35,17:37~39,17:41,17:43~47,17:49,17:51~52,17:55,17:58~59' scan='5'
# ANTENNA 3
# cols: [[ 3 17]]
# Channels:
# lim: 0.085 total # to flag: 15 max: 2 min: 1
# scans:
# lim: 0.085 total # to flag: 1 max: 17 min: 17
# mode='manual' antenna='ea03' spw='17:11,17:13~14,17:16,17:19,17:23,17:35,17:37~39,17:41,17:46~47,17:58~59' scan='5'
# ANTENNA 24
# cols: [[24 14]]
# Channels:
# lim: 0.07 total # to flag: 13 max: 2 min: 1
# scans:
# lim: 0.07 total # to flag: 1 max: 14 min: 14
# mode='manual' antenna='ea24' spw='17:16,17:19~21,17:24~25,17:35,17:41,17:43~45,17:49,17:55' scan='5'
# ANTENNA 4
# cols: [[ 4 14]]
# Channels:
# lim: 0.07 total # to flag: 14 max: 1 min: 1
# scans:
# lim: 0.07 total # to flag: 1 max: 14 min: 14
# mode='manual' antenna='ea04' spw='17:14,17:16,17:18,17:21~22,17:26,17:28~29,17:32~34,17:37,17:51~52' scan='5'
# ANTENNA 8
# cols: [[8 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea08' spw='17:22' scan='17'
# ANTENNA 5
# cols: [[5 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea05' spw='17:22' scan='17'
#
# Spectral window: 18
# antennas:
# lim: 0.96 total # to flag: 4 max: 46 min: 11
# ANTENNA 23
# cols: [[23 46]]
# Channels:
# lim: 0.23 total # to flag: 31 max: 3 min: 1
# scans:
# lim: 0.23 total # to flag: 1 max: 46 min: 46
# mode='manual' antenna='ea23' spw='18:3~9,18:17,18:20~21,18:23,18:25,18:27,18:30~34,18:37,18:39,18:42,18:45~46,18:50~53,18:55,18:58~60' scan='5'
# ANTENNA 3
# cols: [[ 3 22]]
# Channels:
# lim: 0.11 total # to flag: 19 max: 2 min: 1
# scans:
# lim: 0.11 total # to flag: 1 max: 22 min: 22
# mode='manual' antenna='ea03' spw='18:4~6,18:8~10,18:22~23,18:25,18:27,18:33~34,18:37,18:42,18:51~52,18:55,18:59~60' scan='5'
# ANTENNA 24
# cols: [[24 17]]
# Channels:
# lim: 0.085 total # to flag: 16 max: 2 min: 1
# scans:
# lim: 0.085 total # to flag: 1 max: 17 min: 17
# mode='manual' antenna='ea24' spw='18:3,18:8,18:10,18:21~22,18:30~34,18:39,18:45~46,18:50~51,18:53' scan='5'
# ANTENNA 4
# cols: [[ 4 11]]
# Channels:
# lim: 0.055 total # to flag: 10 max: 2 min: 1
# scans:
# lim: 0.055 total # to flag: 1 max: 11 min: 11
# mode='manual' antenna='ea04' spw='18:7,18:17,18:20,18:27,18:34,18:37,18:45~46,18:58,18:60' scan='5'
#
# Spectral window: 19
# antennas:
# lim: 0.64 total # to flag: 4 max: 25 min: 5
# ANTENNA 23
# cols: [[23 25]]
# Channels:
# lim: 0.125 total # to flag: 17 max: 3 min: 1
# scans:
# lim: 0.125 total # to flag: 1 max: 25 min: 25
# mode='manual' antenna='ea23' spw='19:3~8,19:10~11,19:14,19:36~38,19:46,19:52,19:57~58,19:60' scan='5'
# ANTENNA 24
# cols: [[24 20]]
# Channels:
# lim: 0.1 total # to flag: 17 max: 2 min: 1
# scans:
# lim: 0.1 total # to flag: 1 max: 20 min: 20
# mode='manual' antenna='ea24' spw='19:3,19:5~6,19:8,19:10~11,19:14,19:36~38,19:45~46,19:52,19:57~60' scan='5'
# ANTENNA 3
# cols: [[ 3 14]]
# Channels:
# lim: 0.07 total # to flag: 9 max: 2 min: 1
# scans:
# lim: 0.07 total # to flag: 1 max: 14 min: 14
# mode='manual' antenna='ea03' spw='19:6~7,19:36,19:45,19:52,19:57~60' scan='5'
# ANTENNA 4
# cols: [[4 5]]
# Channels:
# lim: 0.025 total # to flag: 5 max: 1 min: 1
# scans:
# lim: 0.025 total # to flag: 1 max: 5 min: 5
# mode='manual' antenna='ea04' spw='19:3~5,19:10,19:60' scan='5'
#
# Spectral window: 20
# antennas:
# lim: 1.18 total # to flag: 4 max: 58 min: 14
# ANTENNA 23
# cols: [[23 58]]
# Channels:
# lim: 0.29 total # to flag: 37 max: 5 min: 1
# scans:
# lim: 0.29 total # to flag: 1 max: 58 min: 58
# mode='manual' antenna='ea23' spw='20:3,20:6~17,20:19~24,20:26~27,20:33,20:36~37,20:40,20:46~47,20:50~59' scan='5'
# ANTENNA 3
# cols: [[ 3 28]]
# Channels:
# lim: 0.14 total # to flag: 25 max: 2 min: 1
# scans:
# lim: 0.14 total # to flag: 1 max: 28 min: 28
# mode='manual' antenna='ea03' spw='20:3,20:7~9,20:11~15,20:19,20:22,20:26~27,20:33,20:36~37,20:40,20:50~55,20:58~59' scan='5'
# ANTENNA 4
# cols: [[ 4 16]]
# Channels:
# lim: 0.08 total # to flag: 16 max: 1 min: 1
# scans:
# lim: 0.08 total # to flag: 1 max: 16 min: 16
# mode='manual' antenna='ea04' spw='20:6,20:11,20:14~17,20:20~22,20:24,20:33,20:46~47,20:51,20:54,20:58' scan='5'
# ANTENNA 24
# cols: [[24 14]]
# Channels:
# lim: 0.07 total # to flag: 12 max: 2 min: 1
# scans:
# lim: 0.07 total # to flag: 1 max: 14 min: 14
# mode='manual' antenna='ea24' spw='20:10,20:17,20:22~24,20:33,20:51,20:55~59' scan='5'
#
# Spectral window: 21
# antennas:
# lim: 0.24 total # to flag: 6 max: 11 min: 1
# ANTENNA 23
# cols: [[23 11]]
# Channels:
# lim: 0.055 total # to flag: 8 max: 2 min: 1
# scans:
# lim: 0.055 total # to flag: 1 max: 11 min: 11
# mode='manual' antenna='ea23' spw='21:3~8,21:14,21:37' scan='5'
# ANTENNA 24
# cols: [[24  6]]
# Channels:
# lim: 0.03 total # to flag: 4 max: 2 min: 1
# scans:
# lim: 0.03 total # to flag: 1 max: 6 min: 6
# mode='manual' antenna='ea24' spw='21:3~6' scan='5'
# ANTENNA 3
# cols: [[3 4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 1 max: 4 min: 4
# mode='manual' antenna='ea03' spw='21:5,21:7~8,21:14' scan='5'
# ANTENNA 28
# cols: [[28  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea28' spw='21:11' scan='156'
# ANTENNA 11
# cols: [[11  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea11' spw='21:11' scan='156'
# ANTENNA 4
# cols: [[4 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea04' spw='21:37' scan='5'
#
# Spectral window: 22
# antennas:
# lim: 0.28 total # to flag: 8 max: 9 min: 2
# ANTENNA 23
# cols: [[23  9]]
# Channels:
# lim: 0.045 total # to flag: 7 max: 3 min: 1
# scans:
# lim: 0.045 total # to flag: 2 max: 8 min: 1
# mode='manual' antenna='ea23' spw='22:11,22:15,22:18,22:43,22:49~51' scan='5,45'
# ANTENNA 24
# cols: [[24  4]]
# Channels:
# lim: 0.02 total # to flag: 3 max: 2 min: 1
# scans:
# lim: 0.02 total # to flag: 1 max: 4 min: 4
# mode='manual' antenna='ea24' spw='22:11,22:49~50' scan='5'
# ANTENNA 4
# cols: [[4 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea04' spw='22:15,22:50~51' scan='5'
# ANTENNA 3
# cols: [[3 3]]
# Channels:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea03' spw='22:18,22:50' scan='5'
# ANTENNA 1
# cols: [[1 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea01' spw='22:7,22:43,22:49' scan='13,21,45'
# ANTENNA 18
# cols: [[18  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# mode='manual' antenna='ea18' spw='22:60' scan='132'
# ANTENNA 12
# cols: [[12  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea12' spw='22:7,22:49' scan='13,21'
# ANTENNA 10
# cols: [[10  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# mode='manual' antenna='ea10' spw='22:60' scan='132'
#
# Spectral window: 23
# antennas:
# lim: 0.16 total # to flag: 4 max: 7 min: 3
# ANTENNA 23
# cols: [[23  7]]
# Channels:
# lim: 0.035 total # to flag: 6 max: 2 min: 1
# scans:
# lim: 0.035 total # to flag: 1 max: 7 min: 7
# mode='manual' antenna='ea23' spw='23:13,23:15~18,23:34' scan='5'
# ANTENNA 24
# cols: [[24  3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea24' spw='23:12~13,23:18' scan='5'
# ANTENNA 4
# cols: [[4 3]]
# Channels:
# lim: 0.015 total # to flag: 2 max: 2 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea04' spw='23:17' scan='5'
# ANTENNA 3
# cols: [[3 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea03' spw='23:12,23:15,23:34' scan='5'
#
# Spectral window: 24
# antennas:
# lim: 0.04 total # to flag: 3 max: 2 min: 1
# ANTENNA 23
# cols: [[23  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# mode='manual' antenna='ea23' spw='24:28,24:31' scan='5'
# ANTENNA 24
# cols: [[24  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea24' spw='24:31' scan='5'
# ANTENNA 3
# cols: [[3 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea03' spw='24:28' scan='5'
#
# Spectral window: 27
# antennas:
# lim: 0.74 total # to flag: 8 max: 32 min: 1
# ANTENNA 23
# cols: [[23 32]]
# Channels:
# lim: 0.16 total # to flag: 22 max: 3 min: 1
# scans:
# lim: 0.16 total # to flag: 3 max: 30 min: 1
# mode='manual' antenna='ea23' spw='27:5~10,27:15~16,27:21,27:23~26,27:32,27:39~41,27:56~60' scan='5,108,112'
# ANTENNA 3
# cols: [[ 3 13]]
# Channels:
# lim: 0.065 total # to flag: 10 max: 2 min: 1
# scans:
# lim: 0.065 total # to flag: 1 max: 13 min: 13
# mode='manual' antenna='ea03' spw='27:8~9,27:39~41,27:56~60' scan='5'
# ANTENNA 24
# cols: [[24 12]]
# Channels:
# lim: 0.06 total # to flag: 9 max: 2 min: 1
# scans:
# lim: 0.06 total # to flag: 1 max: 12 min: 12
# mode='manual' antenna='ea24' spw='27:6~10,27:15~16,27:59~60' scan='5'
# ANTENNA 4
# cols: [[ 4 10]]
# Channels:
# lim: 0.05 total # to flag: 10 max: 1 min: 1
# scans:
# lim: 0.05 total # to flag: 2 max: 9 min: 1
# mode='manual' antenna='ea04' spw='27:5~8,27:16,27:23~26,27:49' scan='5,17'
# ANTENNA 1
# cols: [[1 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea01' spw='27:48~49,27:58' scan='9,17,96'
# ANTENNA 18
# cols: [[18  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea18' spw='27:21,27:32' scan='108,112'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='27:48' scan='96'
# ANTENNA 6
# cols: [[6 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea06' spw='27:58' scan='9'
#
# Spectral window: 28
# antennas:
# lim: 0.14 total # to flag: 8 max: 4 min: 1
# ANTENNA 23
# cols: [[23  4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 2 max: 3 min: 1
# mode='manual' antenna='ea23' spw='28:3,28:6,28:38,28:40' scan='5,65'
# ANTENNA 3
# cols: [[3 3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea03' spw='28:6,28:40,28:42' scan='5'
# ANTENNA 1
# cols: [[1 2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea01' spw='28:7,28:43' scan='25,116'
# ANTENNA 24
# cols: [[24  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea24' spw='28:42' scan='5'
# ANTENNA 14
# cols: [[14  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea14' spw='28:43' scan='116'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='28:7' scan='25'
# ANTENNA 6
# cols: [[6 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea06' spw='28:3' scan='65'
# ANTENNA 4
# cols: [[4 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea04' spw='28:38' scan='5'
#
# Spectral window: 29
# antennas:
# lim: 0.06 total # to flag: 6 max: 1 min: 1
# ANTENNA 23
# cols: [[23  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea23' spw='29:40' scan='5'
# ANTENNA 18
# cols: [[18  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea18' spw='29:54' scan='92'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='29:14' scan='27'
# ANTENNA 11
# cols: [[11  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea11' spw='29:54' scan='92'
# ANTENNA 3
# cols: [[3 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea03' spw='29:40' scan='5'
# ANTENNA 1
# cols: [[1 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea01' spw='29:14' scan='27'
#
# Spectral window: 30
# antennas:
# lim: 0.32 total # to flag: 11 max: 9 min: 1
# ANTENNA 12
# cols: [[12  9]]
# Channels:
# lim: 0.045 total # to flag: 8 max: 2 min: 1
# scans:
# lim: 0.045 total # to flag: 7 max: 2 min: 1
# mode='manual' antenna='ea12' spw='30:28,30:30~32,30:39~40,30:45,30:53' scan='11,13,15,37,47,120,122'
# ANTENNA 23
# cols: [[23  4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 1 max: 4 min: 4
# mode='manual' antenna='ea23' spw='30:32,30:34,30:41,30:44' scan='5'
# ANTENNA 3
# cols: [[3 4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 1 max: 4 min: 4
# mode='manual' antenna='ea03' spw='30:32,30:34,30:41,30:44' scan='5'
# ANTENNA 1
# cols: [[1 4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 3 max: 2 min: 1
# mode='manual' antenna='ea01' spw='30:28,30:30,30:32,30:53' scan='11,13,47'
# ANTENNA 10
# cols: [[10  3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# mode='manual' antenna='ea10' spw='30:39,30:45,30:53' scan='47,120,122'
# ANTENNA 27
# cols: [[27  2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 1 max: 2 min: 2
# mode='manual' antenna='ea27' spw='30:31,30:53' scan='15'
# ANTENNA 6
# cols: [[6 2]]
# Channels:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# scans:
# lim: 0.01 total # to flag: 2 max: 1 min: 1
# mode='manual' antenna='ea06' spw='30:40,30:52' scan='37,41'
# ANTENNA 14
# cols: [[14  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea14' spw='30:46' scan='41'
# ANTENNA 5
# cols: [[5 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea05' spw='30:52' scan='41'
# ANTENNA 4
# cols: [[4 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea04' spw='30:53' scan='47'
# ANTENNA 2
# cols: [[2 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea02' spw='30:46' scan='41'
#
# Spectral window: 9
# antennas:
# lim: 0.1 total # to flag: 5 max: 4 min: 1
# ANTENNA 23
# cols: [[23  4]]
# Channels:
# lim: 0.02 total # to flag: 4 max: 1 min: 1
# scans:
# lim: 0.02 total # to flag: 1 max: 4 min: 4
# mode='manual' antenna='ea23' spw='9:14,9:22,9:36,9:60' scan='5'
# ANTENNA 24
# cols: [[24  3]]
# Channels:
# lim: 0.015 total # to flag: 3 max: 1 min: 1
# scans:
# lim: 0.015 total # to flag: 1 max: 3 min: 3
# mode='manual' antenna='ea24' spw='9:22,9:36,9:60' scan='5'
# ANTENNA 12
# cols: [[12  1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea12' spw='9:42' scan='27'
# ANTENNA 4
# cols: [[4 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea04' spw='9:14' scan='5'
# ANTENNA 1
# cols: [[1 1]]
# Channels:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# scans:
# lim: 0.005 total # to flag: 1 max: 1 min: 1
# mode='manual' antenna='ea01' spw='9:42' scan='27'

# %%
os.system('ls ../casa_logs/ > ls_out.txt')

names=[]
nn = open("ls_out.txt",'r')
for line in nn:
    names.append(line[0:len(line)-1])


com = open("combined.log",'w+')
for k in names:
    fl=open("../casa_logs/%s"%k,'r')
    for line in fl:
        com.write(line)

com.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import os, sys


class flag_out(object):
    def __init__(self, ant1, ant2, spw, chan, scan):
        self.ant1=np.array(ant1, int)
        self.ant2=np.array(ant2, int)
        self.spw=np.array(spw, int)
        self.chan=np.array(chan, int)
        self.scan=np.array(scan, int)
        self.ants=np.concatenate((np.array(ant1, int),np.array(ant2, int)),axis=0)

    def __repr__(self):
        return "<All output in sequrnce: %s, size: %d>" % (len(self.ant1))



def read_output(myfile):
    
    h = open("%s"%myfile,'r')                                                                                                                                                           
                                                                                                                                                                                        
    ant1=[]                                                                                                                                                                             
    ant2=[]                                                                                                                                                                             
    spw=[]                                                                                                                                                                              
    chan=[]                                                                                                                                                                             
    scan=[]                                                                                                                                                                             
                                                                                                                                                                                        
    lines=[]
    all_lines=[]
    
    for line in h:
        if ('locate+' in line) and ('Scan' in line):
            tail=line.split('INFO')[1]
            all_lines.append(line)
            if tail in lines:
                do=0
            else:
                lines.append(tail)
                ant_line=line.split('BL=ea')
                scan_line=ant_line[0].split('Scan=')
                scan.append(scan_line[1].split(' ')[0])
                ant1.append(ant_line[1].split('@')[0])
                ant2_l=ant_line[1].split(' ea')[1]
                ant2.append(ant2_l.split('@')[0])
                spw_l=ant_line[1].split('Spw=')[1]
                spw.append(spw_l.split(' ')[0])
                chan_l=spw_l.split('Chan=')[1]
                chan.append(chan_l.split(' ')[0])
    
    flags=flag_out(ant1, ant2, spw, chan, scan)
    print 'ALL LINES:', len(all_lines), 'NO REPEATERS', len(lines)
    return flags


def out_plot(flags):
    fig = plt.figure()

    x1=0.03
    y1=0.1
    gap=0.07
    l1=0.45
    h1=0.4

    rect1 = [x1, y1+h1+gap, l1, h1]
    rect2 = [x1+l1+gap, y1+h1+gap, l1, h1]
    rect3 = [x1, y1, l1, h1]
    rect4 = [x1+l1+gap, y1, l1, h1]

    ax11 = fig.add_axes(rect1)
    ax21 = fig.add_axes(rect2)
    ax31 = fig.add_axes(rect3) 
    ax41 = fig.add_axes(rect4)

    nums1=ax11.hist(flags.spw, bins=27, color='g')
    ax11.set_title('Spectral windows')

    nums2=ax21.hist(flags.ants, bins=27, color='r')
    ax21.set_title('Antennas')

    nums4=ax31.hist(flags.scan, bins=100, color='y')
    ax31.set_title('Scans')

    nums3=ax41.hist(flags.chan, bins=30, color='b')
    ax41.set_title('Channels')

    plt.gcf().set_size_inches(9, 7)
    plt.plot()
    return

##Calculating which are the most frequent object(thing)
def fr_calc(array, num_object, percents=1., outfile=None):
    size=[]
    for i in range(1,num_object):
        calc=array[(array == i)]
        size.append([i,len(calc)])

    den=100./percents
    threshold=len(array)/den
    #print 'threshold=', threshold
    size_a=np.array(size, int)
    size_new=size_a[(size_a[:,1] > threshold)]
    size_new.view('i8,i8').sort(order=['f1'], axis=0)
    
    for k in range(1,len(size_new)+1):
        #print size_new[len(size_new)-k]
        if outfile != None:
            outfile.write('%s \n'%size_new[len(size_new)-k])
            
    new_size=np.array(list(reversed(size_new)))
    print 'lim:', threshold,'total # to flag:', np.shape(new_size)[0], 'max:', np.amax(new_size[:,1]), 'min:', np.amin(new_size[:,1])
    return new_size

def freq_time_ant(flags, ant_num):
    
    chan_ant1=flags.chan[(flags.ant1 == ant_num)]
    chan_ant2=flags.chan[(flags.ant2 == ant_num)]

    chan_ant=np.concatenate((chan_ant1, chan_ant2), axis=0)
    
    scan_ant1=flags.scan[(flags.ant1 == ant_num)]
    scan_ant2=flags.scan[(flags.ant2 == ant_num)]

    scan_ant=np.concatenate((scan_ant1, scan_ant2), axis=0)
    
    return chan_ant, scan_ant


def print_tilda(array_x):
    my_array=array_x[:,0]
    array=sorted(my_array)
    
    if array[0]+1==array[1]:
        if len(array)>1:
            if array[0]+2!=array[2]:
                array_line='%s~'%array[0]
            else:
                array_line='%s'%array[0]
    else:
        array_line='%s;'%array[0]

    for i in range(1,len(array)-1):
        if (array[i]-1==array[i-1]) and (array[i]+1==array[i+1]):
            if array_line[len(array_line)-1]=='~':
                do=0
            else:
                array_line=array_line+'~'
        else:
            if (array[i]+1==array[i+1]) and (array[i]-1!=array[i-1]):
                array_line=array_line+'%s~'%array[i]
            else:
                array_line=array_line+'%s;'%array[i]
        
    array_l=array_line+'%s'%array[len(array)-1]
    return array_l



def print_output(spw,ant,chan_a,scan_a):
    if ant < 10:
        mode_ant='mode=\'manual\' antenna=\'ea0%s\''%(ant)
    else:
        mode_ant='mode=\'manual\' antenna=\'ea%s\''%(ant)
    
    chan_l=print_tilda(chan_a)
    scan_l=print_tilda(scan_a)
        
    
    command=mode_ant+' spw=\'%s:%s\''%(spw,chan_l)+' scan=\'%s\'\n'%scan_l
    print command
    return command
    #outfile.write('%s'%command)
    
    
def make_command(namefile, casalogname=False):
    
    flags_in=read_output(namefile)
    out_plot(flags_in)
    plt.show()
   
    spw=[]
    for j in flags_in.spw:
        if j in spw:
            kk=2
        else:
            spw.append(j)
            
    if casalogname == True:
        headd='casa'
        outdate=namefile.split('-')[1]
        outnum=outdate[2].split('.')[0]
    else:
        os.system('date \"+%Y-%m-%d %H%M%S\" > mytime')
        kk=open("mytime",'r')
        mytime=kk.read()
        outdate=mytime.split(' ')[0]
        outnum=mytime.split(' ')[1]
        headd=namefile.split('.')[0]
        
        

    g = open("cmd_%s-%s-%s.txt"%(headd,outdate,outnum),'w+')
    
    for spw_num in spw:
        
        print 'Spectral window:', spw_num
        ant1=flags_in.ant1[(flags_in.spw==spw_num)]
        ant2=flags_in.ant2[(flags_in.spw==spw_num)]
        chans=flags_in.chan[(flags_in.spw==spw_num)]
        scans=flags_in.scan[(flags_in.spw==spw_num)]
        spws=flags_in.spw[(flags_in.spw==spw_num)]
        
        flags=flag_out(ant1, ant2, spws, chans, scans)
        out_plot(flags)

        print 'antennas:'
        ants_list=fr_calc(flags.ants, 29, percents=1)

        for i in ants_list[:,0]:
            chan_ant, scan_ant=freq_time_ant(flags, i)

            plt.hist(chan_ant, bins=30, color='b')
            plt.title('ANT %s: Channels'%i)
            plt.show()
            plt.hist(scan_ant, bins=30, color='y')
            plt.title('ANT %s: Scans'%i)
            plt.show()

            print 'ANTENNA %s'%i
            print 'cols:', ants_list[(ants_list[:,0]==i)]
            print 'Channels:'
            chan_list=fr_calc(chan_ant, 62, percents=0.5)
            print 'scans:'
            scan_list=fr_calc(scan_ant, 172,percents=0.5)

            command=print_output(spw_num,i,chan_list,scan_list)

            g.write(command)
    g.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import os, sys


class flag_out(object):
    def __init__(self, ant1, ant2, spw, chan, scan):
        self.ant1=np.array(ant1, int)
        self.ant2=np.array(ant2, int)
        self.spw=np.array(spw, int)
        self.chan=np.array(chan, int)
        self.scan=np.array(scan, int)
        self.ants=np.concatenate((np.array(ant1, int),np.array(ant2, int)),axis=0)

    def __repr__(self):
        return "<All output in sequrnce: %s, size: %d>" % (len(self.ant1))



def read_output(myfile):
    
    h = open("%s"%myfile,'r')                                                                                                                                                           
                                                                                                                                                                                        
    ant1=[]                                                                                                                                                                             
    ant2=[]                                                                                                                                                                             
    spw=[]                                                                                                                                                                              
    chan=[]                                                                                                                                                                             
    scan=[]                                                                                                                                                                             
                                                                                                                                                                                        
    lines=[]
    all_lines=[]
    
    for line in h:
        if ('locate+' in line) and ('Scan' in line):
            tail=line.split('INFO')[1]
            all_lines.append(line)
            if tail in lines:                                                                                                                                                           
                do=0                                                                                                                                                                    
            else:                                                                                                                                                                       
                lines.append(tail)                                                                                                                                                      
                ant_line=line.split('BL=ea')
                scan_line=ant_line[0].split('Scan=')
                scan.append(scan_line[1].split(' ')[0])
                ant1.append(ant_line[1].split('@')[0])
                ant2_l=ant_line[1].split(' ea')[1]
                ant2.append(ant2_l.split('@')[0])
                spw_l=ant_line[1].split('Spw=')[1]
                spw.append(spw_l.split(' ')[0])
                chan_l=spw_l.split('Chan=')[1]
                chan.append(chan_l.split(' ')[0])
    
    flags=flag_out(ant1, ant2, spw, chan, scan)
    print 'ALL LINES:', len(all_lines), 'NO REPEATERS', len(lines)
    return flags


def out_plot(flags):
    fig = plt.figure()

    x1=0.03
    y1=0.1
    gap=0.07
    l1=0.45
    h1=0.4

    rect1 = [x1, y1+h1+gap, l1, h1]
    rect2 = [x1+l1+gap, y1+h1+gap, l1, h1]
    rect3 = [x1, y1, l1, h1]
    rect4 = [x1+l1+gap, y1, l1, h1]

    ax11 = fig.add_axes(rect1)
    ax21 = fig.add_axes(rect2)
    ax31 = fig.add_axes(rect3) 
    ax41 = fig.add_axes(rect4)

    nums1=ax11.hist(flags.spw, bins=27, color='g')
    ax11.set_title('Spectral windows')

    nums2=ax21.hist(flags.ants, bins=27, color='r')
    ax21.set_title('Antennas')

    nums4=ax31.hist(flags.scan, bins=100, color='y')
    ax31.set_title('Scans')

    nums3=ax41.hist(flags.chan, bins=30, color='b')
    ax41.set_title('Channels')

    plt.gcf().set_size_inches(9, 7)
    plt.plot()
    return

##Calculating which are the most frequent object(thing)
def fr_calc(array, num_object, percents=1., outfile=None):
    size=[]
    for i in range(1,num_object):
        calc=array[(array == i)]
        size.append([i,len(calc)])

    den=100./percents
    threshold=len(array)/den
    #print 'threshold=', threshold
    size_a=np.array(size, int)
    size_new=size_a[(size_a[:,1] > threshold)]
    size_new.view('i8,i8').sort(order=['f1'], axis=0)
    
    for k in range(1,len(size_new)+1):
        #print size_new[len(size_new)-k]
        if outfile != None:
            outfile.write('%s \n'%size_new[len(size_new)-k])
            
    new_size=np.array(list(reversed(size_new)))
    print 'lim:', threshold,'total # to flag:', np.shape(new_size)[0], 'max:', np.amax(new_size[:,1]), 'min:', np.amin(new_size[:,1])
    return new_size

def freq_time_ant(flags, ant_num):
    
    chan_ant1=flags.chan[(flags.ant1 == ant_num)]
    chan_ant2=flags.chan[(flags.ant2 == ant_num)]

    chan_ant=np.concatenate((chan_ant1, chan_ant2), axis=0)
    
    scan_ant1=flags.scan[(flags.ant1 == ant_num)]
    scan_ant2=flags.scan[(flags.ant2 == ant_num)]

    scan_ant=np.concatenate((scan_ant1, scan_ant2), axis=0)
    
    return chan_ant, scan_ant


def print_tilda(array_x, spw, sep=',', ar_chan=False):
    if (sep==';') or (ar_chan is False):
        spw=''
    else:
        spw=str(spw)+':'
    my_array=array_x[:,0]
    array=sorted(my_array)
    array_line=''
    if len(array) > 1:
        if array[0]+1==array[1]:
            if len(array)>2:
                if array[0]+2!=array[2]:
                    array_line='%s~'%array[0]
                else:
                    array_line='%s'%array[0]
        else:
            array_line='%s%s%s'%(array[0],sep,spw)

    for i in range(1,len(array)-1):
        if (array[i]-1==array[i-1]) and (array[i]+1==array[i+1]):
            if array_line[len(array_line)-1]=='~':
                do=0
            else:
                array_line=array_line+'~'
        else:
            if (array[i]+1==array[i+1]) and (array[i]-1!=array[i-1]):
                array_line=array_line+'%s~'%array[i]
            else:
                array_line=array_line+'%s%s%s'%(array[i],sep,spw)

    array_l=array_line+'%s'%array[len(array)-1]
    return array_l



def print_output(spw,ant,chan_a,scan_a, sep=',', print_scan=True):
    if ant < 10:
        mode_ant='mode=\'manual\' antenna=\'ea0%s\''%(ant)
    else:
        mode_ant='mode=\'manual\' antenna=\'ea%s\''%(ant)
    
    chan_l=print_tilda(chan_a,sep=sep,spw=spw,ar_chan=True)
    scan_l=print_tilda(scan_a,sep=sep,spw=spw)
        
    if print_scan is True:
        command=mode_ant+' spw=\'%s:%s\''%(spw,chan_l)+' scan=\'%s\'\n'%scan_l
    else:
        command=mode_ant+' spw=\'%s:%s\''%(spw,chan_l)+'\n'
    print command
    return command
    #outfile.write('%s'%command)
    
    
def make_command(namefile, casalogname=False, sep=',', print_scan=True):
    
    flags_in=read_output(namefile)
    out_plot(flags_in)
    plt.show()
   
    spw=[]
    for j in flags_in.spw:
        if j in spw:
            kk=2
        else:
            spw.append(j)
            
    if casalogname == True:
        headd='casa'
        outdate=namefile.split('-')[1]
        outnum=outdate[2].split('.')[0]
    else:
        os.system('date \"+%Y-%m-%d %H%M%S\" > mytime')
        kk=open("mytime",'r')
        mytime=kk.read()
        outdate=mytime.split(' ')[0]
        outnum=mytime.split(' ')[1]
        headd=namefile.split('.')[0]
        
        

    g = open("cmd_%s-%s-%s.txt"%(headd,outdate,outnum),'w+')
    
    for spw_num in spw:
        
        print 'Spectral window:', spw_num
        ant1=flags_in.ant1[(flags_in.spw==spw_num)]
        ant2=flags_in.ant2[(flags_in.spw==spw_num)]
        chans=flags_in.chan[(flags_in.spw==spw_num)]
        scans=flags_in.scan[(flags_in.spw==spw_num)]
        spws=flags_in.spw[(flags_in.spw==spw_num)]
        
        flags=flag_out(ant1, ant2, spws, chans, scans)
        out_plot(flags)

        print 'antennas:'
        ants_list=fr_calc(flags.ants, 29, percents=1)

        for i in ants_list[:,0]:
            chan_ant, scan_ant=freq_time_ant(flags, i)

            plt.hist(chan_ant, bins=30, color='b')
            plt.title('ANT %s: Channels'%i)
            plt.show()
            plt.hist(scan_ant, bins=30, color='y')
            plt.title('ANT %s: Scans'%i)
            plt.show()

            print 'ANTENNA %s'%i
            print 'cols:', ants_list[(ants_list[:,0]==i)]
            print 'Channels:'
            chan_list=fr_calc(chan_ant, 62, percents=0.5)
            print 'scans:'
            scan_list=fr_calc(scan_ant, 172,percents=0.5)

            command=print_output(spw_num,i,chan_list,scan_list,sep=sep, print_scan=print_scan)

            g.write(command)
    g.close()
